# %%
import pandas as pd

data = pd.read_csv('Air_Traffic_Passenger_Statistics.csv')

# %%
data.sample(50)
# Out:
#        Activity Period                 Operating Airline  \
# 4569            200810                   Air New Zealand
# 11110           201306  United Airlines - Pre 07/01/2013
# 4279            200807                              TACA
# 15288           201606                All Nippon Airways
# 15142           201605                         Air China
# 5690            200907                   United Airlines
# 15494           201607              Sun Country Airlines
# 13580           201504                    Etihad Airways
# 15033           201604                   Asiana Airlines
# 17277           201708                 Frontier Airlines
# 3226            200710  United Airlines - Pre 07/01/2013
# 1476            200607  United Airlines - Pre 07/01/2013
# 9054            201112  United Airlines - Pre 07/01/2013
# 11996           201402                  SkyWest Airlines
# 12791           201409               Swiss International
# ...

# %%
data = data[['Operating Airline', 'Operating Airline IATA Code', 'GEO Summary', 'Boarding Area', 'Passenger Count']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d245b8d143a8> in <module>()
# ----> 1 data = data[['Operating Airline', 'Operating Airline IATA Code', 'GEO Region', 'Boarding Area', 'Passenger Count']]
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
data.sample(50)
# Out:
#                       Operating Airline Operating Airline IATA Code  \
# 10468                   Alaska Airlines                          AS
# 3293                      Mesa Airlines                          YV
# 6792           KLM Royal Dutch Airlines                          KL
# 3982                    Delta Air Lines                          DL
# 2986   United Airlines - Pre 07/01/2013                          UA
# 15133                   Virgin Atlantic                          VS
# 12922                   United Airlines                          UA
# 13179                        Aeromexico                          AM
# 6017                 Northwest Airlines                          NW
# 16556          KLM Royal Dutch Airlines                          KL
# 3752                  Frontier Airlines                          F9
# 18807          KLM Royal Dutch Airlines                          KL
# 1591   United Airlines - Pre 07/01/2013                          UA
# ...

# %%
array = ['A']
data.loc[(data['Operating Airline'] == 'Delta Air Lines') & data['Boarding Area'].isin(array)]
# Out:
#       Operating Airline Operating Airline IATA Code    GEO Summary  \
# 6444    Delta Air Lines                          DL  International
# 6445    Delta Air Lines                          DL  International
# 6554    Delta Air Lines                          DL  International
# 6555    Delta Air Lines                          DL  International
# 6664    Delta Air Lines                          DL  International
# 6665    Delta Air Lines                          DL  International
# 6775    Delta Air Lines                          DL  International
# 6776    Delta Air Lines                          DL  International
# 6892    Delta Air Lines                          DL  International
# 6893    Delta Air Lines                          DL  International
# 7013    Delta Air Lines                          DL  International
# 7014    Delta Air Lines                          DL  International
# 7132    Delta Air Lines                          DL  International
# ...
