# %%
import pandas as pd

data = pd.read_csv('Air_Traffic_Passenger_Statistics.csv')

# %%
data.sample(50)
# Out:
#        Activity Period                 Operating Airline  \
# 13104           201412                          Emirates
# 15107           201604                   United Airlines
# 15052           201604                   Delta Air Lines
# 2331            200703                   Delta Air Lines
# 15982           201611                 American Airlines
# 4387            200808                Northwest Airlines
# 19191           201808                   United Airlines
# 2722            200706                        US Airways
# 15977           201611                   Alaska Airlines
# 9070            201112                   Virgin Atlantic
# 16082           201611                   United Airlines
# 4640            200810                              TACA
# 1542            200608                Northwest Airlines
# 12552           201407                      SAS Airlines
# 3057            200709                Northwest Airlines
# ...

# %%
data = data[['Activity Period', 'Operating Airline IATA Code', 'GEO Region', 'Activity Type Code', 'Terminal', 'Passenger Count']]

# %%
data.sample(50)
# Out:
#        Activity Period Operating Airline IATA Code           GEO Region  \
# 12788           201409                          SY                   US
# 17564           201710                          CX                 Asia
# 14532           201512                          NH                 Asia
# 16567           201703                          SK               Europe
# 19178           201808                          UA                 Asia
# 3949            200805                          AC               Canada
# 17941           201712                          UA               Europe
# 3471            200712                          VS               Europe
# 13806           201506                          CX                 Asia
# 18235           201802                          UA          Middle East
# 18607           201805                          AY               Europe
# 10076           201209                          TA      Central America
# ...

# %%
array = ['Canada']
data.loc[(data['Operating Airline IATA Code'] == 'UA') & data['GEO Region'].isin(array)]
# Out:
#        Activity Period Operating Airline IATA Code GEO Region  \
# 103             200507                          UA     Canada
# 104             200507                          UA     Canada
# 105             200507                          UA     Canada
# 222             200508                          UA     Canada
# 223             200508                          UA     Canada
# 341             200509                          UA     Canada
# 342             200509                          UA     Canada
# 343             200509                          UA     Canada
# 458             200510                          UA     Canada
# 459             200510                          UA     Canada
# 460             200510                          UA     Canada
# 572             200511                          UA     Canada
# 573             200511                          UA     Canada
# 683             200512                          UA     Canada
# ...
